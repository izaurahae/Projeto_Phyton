# %%
import pandas as pd
tabela = pd.read_csv("escola_acessivel1.csv")
display(tabela)
# Out:
#        TOTAL_REGISTOS                                            ESCOLA  \
# 0                   1                       CIEP 208 ALCEU AMOROSO LIMA
# 1                   1              EE PADRE ARLINDO IGNACIO DE OLIVEIRA
# 2                   1           EE PRESIDENTE TANCREDO DE ALMEIDA NEVES
# 3                   1             ESCOLA ESTADUAL SATURNINO MARAES NETO
# 4                   1  ESC EST ENS FUN GASTON AUGUSTO SANTOS CESAR CIEP
# ...               ...                                               ...
# 10500               1                             EE FREDERICO ZACARIAS
# 10501               1                 ESC EST ENS FUN LUIZ MOLLER FILHO
# 10502               1               ESC EST ENS FUN WILLY OSCAR KONRATH
# 10503               1              ESC ESTADUAL PEDRO ALMEIDA VALADARES
# 10504               1                               EE FRANCISCO MANUEL
#
#            INEP   ANO  VALOR_DESTINADO
# 0      33049700  2019  R$    15.000,00
# ...

# %% [markdown]
# 2-Escolas Acessíveis 2

# %%
import pandas as pd 
tabela =  pd.read_csv("escola_acessivel2.csv")
display(tabela)
# Out:
#        TOTAL_REGISTOS                                            ESCOLA  \
# 0                   1                       CIEP 208 ALCEU AMOROSO LIMA
# 1                   1              EE PADRE ARLINDO IGNACIO DE OLIVEIRA
# 2                   1           EE PRESIDENTE TANCREDO DE ALMEIDA NEVES
# 3                   1             ESCOLA ESTADUAL SATURNINO MARAES NETO
# 4                   1  ESC EST ENS FUN GASTON AUGUSTO SANTOS CESAR CIEP
# ...               ...                                               ...
# 10500               1                             EE FREDERICO ZACARIAS
# 10501               1                 ESC EST ENS FUN LUIZ MOLLER FILHO
# 10502               1               ESC EST ENS FUN WILLY OSCAR KONRATH
# 10503               1              ESC ESTADUAL PEDRO ALMEIDA VALADARES
# 10504               1                               EE FRANCISCO MANUEL
#
#            INEP   ANO  VALOR_DESTINADO
# 0      33049700  2019  R$    15.000,00
# ...

# %%
import pandas as pd
tabela = pd.read_csv("escola_acessivel1.csv")
display(tabela)
# Out:
#        TOTAL_REGISTOS                                            ESCOLA  \
# 0                   1                       CIEP 208 ALCEU AMOROSO LIMA
# 1                   1              EE PADRE ARLINDO IGNACIO DE OLIVEIRA
# 2                   1           EE PRESIDENTE TANCREDO DE ALMEIDA NEVES
# 3                   1             ESCOLA ESTADUAL SATURNINO MARAES NETO
# 4                   1  ESC EST ENS FUN GASTON AUGUSTO SANTOS CESAR CIEP
# ...               ...                                               ...
# 10500               1                             EE FREDERICO ZACARIAS
# 10501               1                 ESC EST ENS FUN LUIZ MOLLER FILHO
# 10502               1               ESC EST ENS FUN WILLY OSCAR KONRATH
# 10503               1              ESC ESTADUAL PEDRO ALMEIDA VALADARES
# 10504               1                               EE FRANCISCO MANUEL
#
#            INEP   ANO  VALOR_DESTINADO
# 0      33049700  2019  R$    15.000,00
# ...

# %%
import matplotlib.pyplot as plt
